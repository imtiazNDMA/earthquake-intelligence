# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
data = pd.read_json("seismic_events.json", encoding="utf-16")

# %%
data.tail()
# Out:
#        status              message  \
# 13986    True  Seismic Events Data
# 13987    True  Seismic Events Data
# 13988    True  Seismic Events Data
# 13989    True  Seismic Events Data
# 13990    True  Seismic Events Data
#
#                                                     data
# 13986  {'id': 18231, 'mode': 'Manual', 'event_month':...
# 13987  {'id': 18230, 'mode': 'Manual', 'event_month':...
# 13988  {'id': 18946, 'mode': 'Automatic', 'event_mont...
# 13989  {'id': 19060, 'mode': 'Manual', 'event_month':...
# 13990  {'id': 8130, 'mode': 'Manual', 'event_month': ...
